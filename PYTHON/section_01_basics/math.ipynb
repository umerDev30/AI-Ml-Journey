# %%
r = round(5.5)
a = abs(-4)
p = pow(4,5)
ma = max(1,2,3)
mi = min(1,2,3)

print(r)
print(a)
print(p)
print(ma)
print(mi)
# Out:
# 6
# 4
# 1024
# 3
# 1

# %%
import math

print(math.ceil(4.4))
print(math.floor(4.4))
print(math.pi)
print(math.e)
# Out:
# 5
# 4
# 3.141592653589793
# 2.718281828459045

# %%
# Area of cicle

radius = float(input("Enter radius of circle: "))
area = math.pi * pow(radius,2)
print(f"Area of the circle is: {area:.2f} cm^2")
# Out:
# Area of the circle is: 153.94 cm^2

# %%
# Hypotenuse of rigth triangle

a = float(input("Enter lenght of side a : "))
b = float(input("Enter lenght of side b : "))

c = math.sqrt(pow(a,2) + pow(b,2))
print(f"Side or c is: {round(c,2)}cm")
# Out:
# Hypotenuse of rigth triangle or c is: 9.22cm

# %%
# Circumference of a circle

radius = float(input("Enter radius of circle: "))
c = 2 * math.pi * r
print(f"Circumference if the circle is: {c:.2f}cm")
# Out:
# Circumference if the circle is: 37.70cm
