# %%
# creating new directory

import os

new_directory = os.mkdir("Uni")
print(new_directory)

# %%
content = os.listdir('.') # . mean content of current directory
print(content)
# Out:
# ['des_example.txt', 'example_1.txt', 'file_path.ipynb', 'jerry.txt', 'part_01.ipynb', 'Uni']

# %%
# joining paths

folder_name = "uni"
file_name = "mars.txt"
relative_path = os.path.join(folder_name,file_name)
print(relative_path)
# Out:
# uni\mars.txt

# %%
folder_name= "uni"
file_name = "mars.txt"
absolute_path = os.path.join(os.getcwd(),folder_name,file_name)
print(absolute_path)
# Out:
# d:\ML Bootcamp\python\section_06_file_operations\uni\mars.txt

# %%
path = "file_path_example.txt"
if os.path.exists(path):
    print(f"The path {path} exist.")
else:
    print(f"The path {path} does not exist.")
# Out:
# The path file_path_example.txt does not exist.

# %%
path = "file_path_example.txt"
if os.path.isfile(path):
    print(f"The path {path} exist as file.")
elif os.path.isdir(path):
    print(f"The path {path} exist as directory.") 
else: 
    print(f"The path {path} is neither file nor directory.")
# Out:
# The path file_path_example.txt is neither file nor directory.

# %%
relative_path = "mars.txt"
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\ML Bootcamp\python\section_06_file_operations\mars.txt
